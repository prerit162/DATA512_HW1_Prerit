# %%
# 
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Step 1 : Data Acquisition

# %% [markdown]
# ### License
#
# Code Owner : Dr. David W. McDonald
#
# Creative Commons CC-BY license. Revision 1.2 - August 14, 2023

# %%
#########
#
#    CONSTANTS
#

# The REST API 'pageviews' URL - this is the common URL/endpoint for all 'pageviews' API requests
API_REQUEST_PAGEVIEWS_ENDPOINT = 'https://wikimedia.org/api/rest_v1/metrics/pageviews/'

# This is a parameterized string that specifies what kind of pageviews request we are going to make
# In this case it will be a 'per-article' based request. The string is a format string so that we can
# replace each parameter with an appropriate value before making the request
API_REQUEST_PER_ARTICLE_PARAMS = 'per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}'

# The Pageviews API asks that we not exceed 100 requests per second, we add a small delay to each request
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making a request to the Wikimedia API they ask that you include your email address which will allow them
# to contact you if something happens - such as - your code exceeding rate limits - or some other error 
REQUEST_HEADERS = {
    'User-Agent': '<prerit16@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2023',
}

# This is just a list of English Wikipedia article titles that we can use for example requests
#ARTICLE_TITLES = [ 'Bison', 'Northern flicker', 'Red squirrel', 'Chinook salmon', 'Horseshoe bat' ]

# This template is used to map parameter values into the API_REQUST_PER_ARTICLE_PARAMS portion of an API request. The dictionary has a
# field/key for each of the required parameters. In the example, below, we only vary the article name, so the majority of the fields
# can stay constant for each request. Of course, these values *could* be changed if necessary.
ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE = {
    "project":     "en.wikipedia.org",
    "access":      "desktop",      # this should be changed for the different access types
    "agent":       "user",
    "article":     "",             # this value will be set/changed before each request
    "granularity": "monthly",
    "start":       "2015070100",   # start and end dates need to be set
    "end":         "2023093000"    # this is likely the wrong end date
}

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageviews_per_article(article_title = None, 
                                  endpoint_url = API_REQUEST_PAGEVIEWS_ENDPOINT, 
                                  endpoint_params = API_REQUEST_PER_ARTICLE_PARAMS, 
                                  request_template = ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE,
                                  headers = REQUEST_HEADERS):

    # article title can be as a parameter to the call or in the request_template
    if article_title:
        request_template['article'] = article_title

    if not request_template['article']:
        raise Exception("Must supply an article title to make a pageviews request.")

    # Titles are supposed to have spaces replaced with "_" and be URL encoded
    article_title_encoded = urllib.parse.quote(request_template['article'].replace(' ','_'))
    request_template['article'] = article_title_encoded
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
data = pd.read_excel('../Data/thank_the_academy.AUG.2023.csv.xlsx')

# %%
data
# Out:
#                                             name  \
# 0              Everything Everywhere All at Once
# 1     All Quiet on the Western Front (2022 film)
# 2                          The Whale (2022 film)
# 3                              Top Gun: Maverick
# 4                 Black Panther: Wakanda Forever
# ...                                          ...
# 1354                     The Yankee Doodle Mouse
# 1355                    The Yearling (1946 film)
# 1356               Yesterday, Today and Tomorrow
# 1357           You Can't Take It with You (film)
# 1358                      Zorba the Greek (film)
#
#                                                     url
# 0     https://en.wikipedia.org/wiki/Everything_Every...
# 1     https://en.wikipedia.org/wiki/All_Quiet_on_the...
# 2     https://en.wikipedia.org/wiki/The_Whale_(2022_...
# 3       https://en.wikipedia.org/wiki/Top_Gun:_Maverick
# 4     https://en.wikipedia.org/wiki/Black_Panther:_W...
# ...                                                 ...
# 1354  https://en.wikipedia.org/wiki/The_Yankee_Doodl...
# 1355  https://en.wikipedia.org/wiki/The_Yearling_(19...
# 1356  https://en.wikipedia.org/wiki/Yesterday,_Today...
# 1357  https://en.wikipedia.org/wiki/You_Can't_Take_I...
# 1358  https://en.wikipedia.org/wiki/Zorba_the_Greek_...
#
# [1359 rows x 2 columns]

# %%
len(data)
# Out:
# 1359

# %%
access = ['all-access','desktop','mobile-web','mobile-app']
#filtered_data = pd.DataFrame(columns = ['project','article','granularity','timestamp','access','agent','views'])
filtered_data = []
for index, row in data.iterrows():
    try: 
        for i in access:
            ARTICLE_PAGEVIEWS_PARAMS_TEMPLATE['access'] = i
            views = request_pageviews_per_article(row['name'])
            filtered_data.append(pd.json_normalize(views['items']))
            print(f"Data Fetched for {row['name']}")
    except:
        print(f"Request Failed for {row['name']}")
# Out:
# Data Fetched for Everything Everywhere All at Once
# Data Fetched for Everything Everywhere All at Once
# Data Fetched for Everything Everywhere All at Once
# Data Fetched for Everything Everywhere All at Once
# Data Fetched for All Quiet on the Western Front (2022 film)
# Data Fetched for All Quiet on the Western Front (2022 film)
# Data Fetched for All Quiet on the Western Front (2022 film)
# Data Fetched for All Quiet on the Western Front (2022 film)
# Data Fetched for The Whale (2022 film)
# Data Fetched for The Whale (2022 film)
# Data Fetched for The Whale (2022 film)
# Data Fetched for The Whale (2022 film)
# Data Fetched for Top Gun: Maverick
# Data Fetched for Top Gun: Maverick
# Data Fetched for Top Gun: Maverick
# Data Fetched for Top Gun: Maverick
# Data Fetched for Black Panther: Wakanda Forever
# Data Fetched for Black Panther: Wakanda Forever
# Data Fetched for Black Panther: Wakanda Forever
# Data Fetched for Black Panther: Wakanda Forever
# Data Fetched for Avatar: The Way of Water
# Data Fetched for Avatar: The Way of Water
# Data Fetched for Avatar: The Way of Water
# Data Fetched for Avatar: The Way of Water
# Data Fetched for Women Talking (film)
# Data Fetched for Women Talking (film)
# Data Fetched for Women Talking (film)
# Data Fetched for Women Talking (film)
# Data Fetched for Guillermo del Toro's Pinocchio
# Data Fetched for Guillermo del Toro's Pinocchio
# Data Fetched for Guillermo del Toro's Pinocchio
# Data Fetched for Guillermo del Toro's Pinocchio
# Data Fetched for Navalny (film)
# Data Fetched for Navalny (film)
# Data Fetched for Navalny (film)
# Data Fetched for Navalny (film)
# Data Fetched for The Elephant Whisperers
# Data Fetched for The Elephant Whisperers
# Data Fetched for The Elephant Whisperers
# Data Fetched for The Elephant Whisperers
# Data Fetched for An Irish Goodbye
# Data Fetched for An Irish Goodbye
# Data Fetched for An Irish Goodbye
# Data Fetched for An Irish Goodbye
# Data Fetched for The Boy, the Mole, the Fox and the Horse (film)
# Data Fetched for The Boy, the Mole, the Fox and the Horse (film)
# Data Fetched for The Boy, the Mole, the Fox and the Horse (film)
# Data Fetched for The Boy, the Mole, the Fox and the Horse (film)
# Data Fetched for RRR (film)
# Data Fetched for RRR (film)
# Data Fetched for RRR (film)
# Data Fetched for RRR (film)
# Data Fetched for CODA (2021 film)
# Data Fetched for CODA (2021 film)
# Data Fetched for CODA (2021 film)
# Data Fetched for CODA (2021 film)
# Data Fetched for Dune (2021 film)
# Data Fetched for Dune (2021 film)
# Data Fetched for Dune (2021 film)
# Data Fetched for Dune (2021 film)
# Data Fetched for The Eyes of Tammy Faye (2021 film)
# Data Fetched for The Eyes of Tammy Faye (2021 film)
# Data Fetched for The Eyes of Tammy Faye (2021 film)
# Data Fetched for The Eyes of Tammy Faye (2021 film)
# Data Fetched for No Time to Die
# Data Fetched for No Time to Die
# Data Fetched for No Time to Die
# Data Fetched for No Time to Die
# Data Fetched for The Windshield Wiper
# Data Fetched for The Windshield Wiper
# Data Fetched for The Windshield Wiper
# Data Fetched for The Windshield Wiper
# Data Fetched for The Long Goodbye (Riz Ahmed album)
# Data Fetched for The Long Goodbye (Riz Ahmed album)
# Data Fetched for The Long Goodbye (Riz Ahmed album)
# Data Fetched for The Long Goodbye (Riz Ahmed album)
# Data Fetched for The Queen of Basketball
# Data Fetched for The Queen of Basketball
# Data Fetched for The Queen of Basketball
# Data Fetched for The Queen of Basketball
# Data Fetched for Summer of Soul
# Data Fetched for Summer of Soul
# Data Fetched for Summer of Soul
# Data Fetched for Summer of Soul
# Data Fetched for Drive My Car (film)
# Data Fetched for Drive My Car (film)
# Data Fetched for Drive My Car (film)
# Data Fetched for Drive My Car (film)
# Data Fetched for Encanto
# Data Fetched for Encanto
# Data Fetched for Encanto
# Data Fetched for Encanto
# Data Fetched for West Side Story (2021 film)
# Data Fetched for West Side Story (2021 film)
# Data Fetched for West Side Story (2021 film)
# Data Fetched for West Side Story (2021 film)
# Data Fetched for Belfast (film)
# Data Fetched for Belfast (film)
# Data Fetched for Belfast (film)
# Data Fetched for Belfast (film)
# Data Fetched for The Power of the Dog (film)
# Data Fetched for The Power of the Dog (film)
# Data Fetched for The Power of the Dog (film)
# Data Fetched for The Power of the Dog (film)
# Data Fetched for King Richard (film)
# Data Fetched for King Richard (film)
# Data Fetched for King Richard (film)
# Data Fetched for King Richard (film)
# Data Fetched for Cruella (film)
# Data Fetched for Cruella (film)
# Data Fetched for Cruella (film)
# Data Fetched for Cruella (film)
# Data Fetched for Nomadland (film)
# Data Fetched for Nomadland (film)
# Data Fetched for Nomadland (film)
# Data Fetched for Nomadland (film)
# Data Fetched for The Father (2020 film)
# Data Fetched for The Father (2020 film)
# Data Fetched for The Father (2020 film)
# Data Fetched for The Father (2020 film)
# Data Fetched for Judas and the Black Messiah
# Data Fetched for Judas and the Black Messiah
# Data Fetched for Judas and the Black Messiah
# Data Fetched for Judas and the Black Messiah
# Data Fetched for Minari (film)
# Data Fetched for Minari (film)
# Data Fetched for Minari (film)
# Data Fetched for Minari (film)
# Data Fetched for Mank
# Data Fetched for Mank
# Data Fetched for Mank
# Data Fetched for Mank
# Data Fetched for Sound of Metal
# Data Fetched for Sound of Metal
# Data Fetched for Sound of Metal
# Data Fetched for Sound of Metal
# Data Fetched for Ma Rainey's Black Bottom (film)
# Data Fetched for Ma Rainey's Black Bottom (film)
# Data Fetched for Ma Rainey's Black Bottom (film)
# Data Fetched for Ma Rainey's Black Bottom (film)
# Data Fetched for Promising Young Woman
# Data Fetched for Promising Young Woman
# Data Fetched for Promising Young Woman
# Data Fetched for Promising Young Woman
# Data Fetched for Tenet (film)
# Data Fetched for Tenet (film)
# Data Fetched for Tenet (film)
# Data Fetched for Tenet (film)
# Data Fetched for Soul (2020 film)
# Data Fetched for Soul (2020 film)
# Data Fetched for Soul (2020 film)
# Data Fetched for Soul (2020 film)
# Data Fetched for Another Round (film)
# Data Fetched for Another Round (film)
# Data Fetched for Another Round (film)
# Data Fetched for Another Round (film)
# Data Fetched for My Octopus Teacher
# Data Fetched for My Octopus Teacher
# Data Fetched for My Octopus Teacher
# Data Fetched for My Octopus Teacher
# Data Fetched for Colette (2020 film)
# Data Fetched for Colette (2020 film)
# Data Fetched for Colette (2020 film)
# Data Fetched for Colette (2020 film)
# Data Fetched for If Anything Happens I Love You
# Data Fetched for If Anything Happens I Love You
# Data Fetched for If Anything Happens I Love You
# Data Fetched for If Anything Happens I Love You
# Data Fetched for Two Distant Strangers
# Data Fetched for Two Distant Strangers
# Data Fetched for Two Distant Strangers
# Data Fetched for Two Distant Strangers
# Data Fetched for Parasite (2019 film)
# Data Fetched for Parasite (2019 film)
# Data Fetched for Parasite (2019 film)
# Data Fetched for Parasite (2019 film)
# Data Fetched for Ford v Ferrari
# Data Fetched for Ford v Ferrari
# Data Fetched for Ford v Ferrari
# Data Fetched for Ford v Ferrari
# Data Fetched for Learning to Skateboard in a Warzone (If You're a Girl)
# Data Fetched for Learning to Skateboard in a Warzone (If You're a Girl)
# Data Fetched for Learning to Skateboard in a Warzone (If You're a Girl)
# Data Fetched for Learning to Skateboard in a Warzone (If You're a Girl)
# Data Fetched for The Neighbors' Window
# Data Fetched for The Neighbors' Window
# Data Fetched for The Neighbors' Window
# Data Fetched for The Neighbors' Window
# Data Fetched for Little Women (2019 film)
# Data Fetched for Little Women (2019 film)
# Data Fetched for Little Women (2019 film)
# Data Fetched for Little Women (2019 film)
# Data Fetched for Marriage Story
# Data Fetched for Marriage Story
# Data Fetched for Marriage Story
# Data Fetched for Marriage Story
# Data Fetched for Jojo Rabbit
# Data Fetched for Jojo Rabbit
# Data Fetched for Jojo Rabbit
# Data Fetched for Jojo Rabbit
# Data Fetched for Toy Story 4
# Data Fetched for Toy Story 4
# Data Fetched for Toy Story 4
# Data Fetched for Toy Story 4
# Data Fetched for Joker (2019 film)
# Data Fetched for Joker (2019 film)
# Data Fetched for Joker (2019 film)
# Data Fetched for Joker (2019 film)
# Data Fetched for Once Upon a Time in Hollywood
# Data Fetched for Once Upon a Time in Hollywood
# Data Fetched for Once Upon a Time in Hollywood
# Data Fetched for Once Upon a Time in Hollywood
# Data Fetched for 1917 (2019 film)
# Data Fetched for 1917 (2019 film)
# Data Fetched for 1917 (2019 film)
# Data Fetched for 1917 (2019 film)
# Data Fetched for Judy (film)
# Data Fetched for Judy (film)
# Data Fetched for Judy (film)
# Data Fetched for Judy (film)
# Data Fetched for Bombshell (2019 film)
# Data Fetched for Bombshell (2019 film)
# Data Fetched for Bombshell (2019 film)
# Data Fetched for Bombshell (2019 film)
# Data Fetched for Rocketman (film)
# Data Fetched for Rocketman (film)
# Data Fetched for Rocketman (film)
# Data Fetched for Rocketman (film)
# Data Fetched for American Factory
# Data Fetched for American Factory
# Data Fetched for American Factory
# Data Fetched for American Factory
# Data Fetched for Hair Love
# Data Fetched for Hair Love
# Data Fetched for Hair Love
# Data Fetched for Hair Love
# Data Fetched for Green Book (film)
# Data Fetched for Green Book (film)
# Data Fetched for Green Book (film)
# Data Fetched for Green Book (film)
# Data Fetched for Bohemian Rhapsody (film)
# Data Fetched for Bohemian Rhapsody (film)
# Data Fetched for Bohemian Rhapsody (film)
# Data Fetched for Bohemian Rhapsody (film)
# Data Fetched for Roma (2018 film)
# Data Fetched for Roma (2018 film)
# Data Fetched for Roma (2018 film)
# Data Fetched for Roma (2018 film)
# Data Fetched for Black Panther (film)
# Data Fetched for Black Panther (film)
# Data Fetched for Black Panther (film)
# Data Fetched for Black Panther (film)
# Data Fetched for The Favourite
# Data Fetched for The Favourite
# Data Fetched for The Favourite
# Data Fetched for The Favourite
# Data Fetched for A Star Is Born (2018 film)
# Data Fetched for A Star Is Born (2018 film)
# Data Fetched for A Star Is Born (2018 film)
# Data Fetched for A Star Is Born (2018 film)
# Data Fetched for Vice (2018 film)
# Data Fetched for Vice (2018 film)
# Data Fetched for Vice (2018 film)
# Data Fetched for Vice (2018 film)
# Data Fetched for BlacKkKlansman
# Data Fetched for BlacKkKlansman
# Data Fetched for BlacKkKlansman
# Data Fetched for BlacKkKlansman
# Data Fetched for First Man (film)
# Data Fetched for First Man (film)
# Data Fetched for First Man (film)
# Data Fetched for First Man (film)
# Data Fetched for If Beale Street Could Talk (film)
# Data Fetched for If Beale Street Could Talk (film)
# Data Fetched for If Beale Street Could Talk (film)
# Data Fetched for If Beale Street Could Talk (film)
# Data Fetched for Bao (film)
# Data Fetched for Bao (film)
# Data Fetched for Bao (film)
# Data Fetched for Bao (film)
# Data Fetched for Free Solo
# Data Fetched for Free Solo
# Data Fetched for Free Solo
# Data Fetched for Free Solo
# Data Fetched for Period. End of Sentence.
# Data Fetched for Period. End of Sentence.
# Data Fetched for Period. End of Sentence.
# Data Fetched for Period. End of Sentence.
# Data Fetched for Skin (2018 short film)
# Data Fetched for Skin (2018 short film)
# Data Fetched for Skin (2018 short film)
# Data Fetched for Skin (2018 short film)
# Data Fetched for Spider-Man: Into the Spider-Verse
# Data Fetched for Spider-Man: Into the Spider-Verse
# Data Fetched for Spider-Man: Into the Spider-Verse
# Data Fetched for Spider-Man: Into the Spider-Verse
# Data Fetched for The Shape of Water
# Data Fetched for The Shape of Water
# Data Fetched for The Shape of Water
# Data Fetched for The Shape of Water
# Data Fetched for Dunkirk (2017 film)
# Data Fetched for Dunkirk (2017 film)
# Data Fetched for Dunkirk (2017 film)
# Data Fetched for Dunkirk (2017 film)
# Data Fetched for Three Billboards Outside Ebbing, Missouri
# Data Fetched for Three Billboards Outside Ebbing, Missouri
# Data Fetched for Three Billboards Outside Ebbing, Missouri
# Data Fetched for Three Billboards Outside Ebbing, Missouri
# Data Fetched for Darkest Hour (film)
# Data Fetched for Darkest Hour (film)
# Data Fetched for Darkest Hour (film)
# Data Fetched for Darkest Hour (film)
# Data Fetched for Blade Runner 2049
# Data Fetched for Blade Runner 2049
# Data Fetched for Blade Runner 2049
# Data Fetched for Blade Runner 2049
# Data Fetched for Coco (2017 film)
# Data Fetched for Coco (2017 film)
# Data Fetched for Coco (2017 film)
# Data Fetched for Coco (2017 film)
# Data Fetched for Phantom Thread
# Data Fetched for Phantom Thread
# Data Fetched for Phantom Thread
# Data Fetched for Phantom Thread
# Data Fetched for Call Me by Your Name (film)
# Data Fetched for Call Me by Your Name (film)
# Data Fetched for Call Me by Your Name (film)
# Data Fetched for Call Me by Your Name (film)
# Data Fetched for Get Out
# Data Fetched for Get Out
# Data Fetched for Get Out
# Data Fetched for Get Out
# Data Fetched for I, Tonya
# Data Fetched for I, Tonya
# Data Fetched for I, Tonya
# Data Fetched for I, Tonya
# Data Fetched for Dear Basketball
# Data Fetched for Dear Basketball
# Data Fetched for Dear Basketball
# Data Fetched for Dear Basketball
# Data Fetched for A Fantastic Woman
# Data Fetched for A Fantastic Woman
# Data Fetched for A Fantastic Woman
# Data Fetched for A Fantastic Woman
# Data Fetched for Heaven Is a Traffic Jam on the 405
# Data Fetched for Heaven Is a Traffic Jam on the 405
# Data Fetched for Heaven Is a Traffic Jam on the 405
# Data Fetched for Heaven Is a Traffic Jam on the 405
# Data Fetched for Icarus (2017 film)
# Data Fetched for Icarus (2017 film)
# Data Fetched for Icarus (2017 film)
# Data Fetched for Icarus (2017 film)
# Data Fetched for The Silent Child
# Data Fetched for The Silent Child
# Data Fetched for The Silent Child
# Data Fetched for The Silent Child
# Data Fetched for Flesh and Sand
# Data Fetched for Flesh and Sand
# Data Fetched for Flesh and Sand
# Data Fetched for Flesh and Sand
# Data Fetched for Moonlight (2016 film)
# Data Fetched for Moonlight (2016 film)
# Data Fetched for Moonlight (2016 film)
# Data Fetched for Moonlight (2016 film)
# Data Fetched for La La Land (film)
# Data Fetched for La La Land (film)
# Data Fetched for La La Land (film)
# Data Fetched for La La Land (film)
# Data Fetched for Hacksaw Ridge
# Data Fetched for Hacksaw Ridge
# Data Fetched for Hacksaw Ridge
# Data Fetched for Hacksaw Ridge
# Data Fetched for Manchester by the Sea (film)
# Data Fetched for Manchester by the Sea (film)
# Data Fetched for Manchester by the Sea (film)
# Data Fetched for Manchester by the Sea (film)
# Data Fetched for Arrival (film)
# Data Fetched for Arrival (film)
# Data Fetched for Arrival (film)
# Data Fetched for Arrival (film)
# Data Fetched for Fences (film)
# Data Fetched for Fences (film)
# Data Fetched for Fences (film)
# Data Fetched for Fences (film)
# Data Fetched for Fantastic Beasts and Where to Find Them (film)
# Data Fetched for Fantastic Beasts and Where to Find Them (film)
# Data Fetched for Fantastic Beasts and Where to Find Them (film)
# Data Fetched for Fantastic Beasts and Where to Find Them (film)
# Data Fetched for The Jungle Book (2016 film)
# Data Fetched for The Jungle Book (2016 film)
# Data Fetched for The Jungle Book (2016 film)
# Data Fetched for The Jungle Book (2016 film)
# Data Fetched for O.J.: Made in America
# Data Fetched for O.J.: Made in America
# Data Fetched for O.J.: Made in America
# Data Fetched for O.J.: Made in America
# Data Fetched for Piper (film)
# Data Fetched for Piper (film)
# Data Fetched for Piper (film)
# Data Fetched for Piper (film)
# Data Fetched for The Salesman (2016 film)
# Data Fetched for The Salesman (2016 film)
# Data Fetched for The Salesman (2016 film)
# Data Fetched for The Salesman (2016 film)
# Data Fetched for Sing (2016 Hungarian film)
# Data Fetched for Sing (2016 Hungarian film)
# Data Fetched for Sing (2016 Hungarian film)
# Data Fetched for Sing (2016 Hungarian film)
# Data Fetched for Suicide Squad (2016 film)
# Data Fetched for Suicide Squad (2016 film)
# Data Fetched for Suicide Squad (2016 film)
# Data Fetched for Suicide Squad (2016 film)
# Data Fetched for The White Helmets (film)
# Data Fetched for The White Helmets (film)
# Data Fetched for The White Helmets (film)
# Data Fetched for The White Helmets (film)
# Data Fetched for Zootopia
# Data Fetched for Zootopia
# Data Fetched for Zootopia
# Data Fetched for Zootopia
# Data Fetched for Spotlight (film)
# Data Fetched for Spotlight (film)
# Data Fetched for Spotlight (film)
# Data Fetched for Spotlight (film)
# Data Fetched for Mad Max: Fury Road
# Data Fetched for Mad Max: Fury Road
# Data Fetched for Mad Max: Fury Road
# Data Fetched for Mad Max: Fury Road
# Data Fetched for The Revenant (2015 film)
# Data Fetched for The Revenant (2015 film)
# Data Fetched for The Revenant (2015 film)
# Data Fetched for The Revenant (2015 film)
# Data Fetched for Bridge of Spies (film)
# Data Fetched for Bridge of Spies (film)
# Data Fetched for Bridge of Spies (film)
# Data Fetched for Bridge of Spies (film)
# Data Fetched for The Big Short (film)
# Data Fetched for The Big Short (film)
# Data Fetched for The Big Short (film)
# Data Fetched for The Big Short (film)
# Data Fetched for The Danish Girl (film)
# Data Fetched for The Danish Girl (film)
# Data Fetched for The Danish Girl (film)
# Data Fetched for The Danish Girl (film)
# Data Fetched for Room (2015 film)
# Data Fetched for Room (2015 film)
# Data Fetched for Room (2015 film)
# Data Fetched for Room (2015 film)
# Data Fetched for The Hateful Eight
# Data Fetched for The Hateful Eight
# Data Fetched for The Hateful Eight
# Data Fetched for The Hateful Eight
# Data Fetched for Ex Machina (film)
# Data Fetched for Ex Machina (film)
# Data Fetched for Ex Machina (film)
# Data Fetched for Ex Machina (film)
# Data Fetched for Inside Out (2015 film)
# Data Fetched for Inside Out (2015 film)
# Data Fetched for Inside Out (2015 film)
# Data Fetched for Inside Out (2015 film)
# Data Fetched for Amy (2015 film)
# Data Fetched for Amy (2015 film)
# Data Fetched for Amy (2015 film)
# Data Fetched for Amy (2015 film)
# Data Fetched for Bear Story
# Data Fetched for Bear Story
# Data Fetched for Bear Story
# Data Fetched for Bear Story
# Data Fetched for A Girl in the River: The Price of Forgiveness
# Data Fetched for A Girl in the River: The Price of Forgiveness
# Data Fetched for A Girl in the River: The Price of Forgiveness
# Data Fetched for A Girl in the River: The Price of Forgiveness
# Data Fetched for Son of Saul
# Data Fetched for Son of Saul
# Data Fetched for Son of Saul
# Data Fetched for Son of Saul
# Data Fetched for Spectre (2015 film)
# Data Fetched for Spectre (2015 film)
# Data Fetched for Spectre (2015 film)
# Data Fetched for Spectre (2015 film)
# Data Fetched for Stutterer (film)
# Data Fetched for Stutterer (film)
# Data Fetched for Stutterer (film)
# Data Fetched for Stutterer (film)
# Data Fetched for Birdman (film)
# Data Fetched for Birdman (film)
# Data Fetched for Birdman (film)
# Data Fetched for Birdman (film)
# Data Fetched for The Grand Budapest Hotel
# Data Fetched for The Grand Budapest Hotel
# Data Fetched for The Grand Budapest Hotel
# Data Fetched for The Grand Budapest Hotel
# Data Fetched for Whiplash (2014 film)
# Data Fetched for Whiplash (2014 film)
# Data Fetched for Whiplash (2014 film)
# Data Fetched for Whiplash (2014 film)
# Data Fetched for The Imitation Game
# Data Fetched for The Imitation Game
# Data Fetched for The Imitation Game
# Data Fetched for The Imitation Game
# Data Fetched for American Sniper
# Data Fetched for American Sniper
# Data Fetched for American Sniper
# Data Fetched for American Sniper
# Data Fetched for Boyhood (2014 film)
# Data Fetched for Boyhood (2014 film)
# Data Fetched for Boyhood (2014 film)
# Data Fetched for Boyhood (2014 film)
# Data Fetched for Interstellar (film)
# Data Fetched for Interstellar (film)
# Data Fetched for Interstellar (film)
# Data Fetched for Interstellar (film)
# Data Fetched for The Theory of Everything (2014 film)
# Data Fetched for The Theory of Everything (2014 film)
# Data Fetched for The Theory of Everything (2014 film)
# Data Fetched for The Theory of Everything (2014 film)
# Data Fetched for Ida (film)
# Data Fetched for Ida (film)
# Data Fetched for Ida (film)
# Data Fetched for Ida (film)
# Data Fetched for Selma (film)
# Data Fetched for Selma (film)
# Data Fetched for Selma (film)
# Data Fetched for Selma (film)
# Data Fetched for Citizenfour
# Data Fetched for Citizenfour
# Data Fetched for Citizenfour
# Data Fetched for Citizenfour
# Data Fetched for Big Hero 6 (film)
# Data Fetched for Big Hero 6 (film)
# Data Fetched for Big Hero 6 (film)
# Data Fetched for Big Hero 6 (film)
# Data Fetched for Crisis Hotline: Veterans Press 1
# Data Fetched for Crisis Hotline: Veterans Press 1
# Data Fetched for Crisis Hotline: Veterans Press 1
# Data Fetched for Crisis Hotline: Veterans Press 1
# Data Fetched for The Phone Call (2013 film)
# Data Fetched for The Phone Call (2013 film)
# Data Fetched for The Phone Call (2013 film)
# Data Fetched for The Phone Call (2013 film)
# Data Fetched for Still Alice
# Data Fetched for Still Alice
# Data Fetched for Still Alice
# Data Fetched for Still Alice
# Data Fetched for Feast (2014 film)
# Data Fetched for Feast (2014 film)
# Data Fetched for Feast (2014 film)
# Data Fetched for Feast (2014 film)
# Data Fetched for 12 Years a Slave (film)
# Data Fetched for 12 Years a Slave (film)
# Data Fetched for 12 Years a Slave (film)
# Data Fetched for 12 Years a Slave (film)
# Data Fetched for Gravity (2013 film)
# Data Fetched for Gravity (2013 film)
# Data Fetched for Gravity (2013 film)
# Data Fetched for Gravity (2013 film)
# Data Fetched for Dallas Buyers Club
# Data Fetched for Dallas Buyers Club
# Data Fetched for Dallas Buyers Club
# Data Fetched for Dallas Buyers Club
# Data Fetched for Frozen (2013 film)
# Data Fetched for Frozen (2013 film)
# Data Fetched for Frozen (2013 film)
# Data Fetched for Frozen (2013 film)
# Data Fetched for The Great Gatsby (2013 film)
# Data Fetched for The Great Gatsby (2013 film)
# Data Fetched for The Great Gatsby (2013 film)
# Data Fetched for The Great Gatsby (2013 film)
# Data Fetched for Her (film)
# Data Fetched for Her (film)
# Data Fetched for Her (film)
# Data Fetched for Her (film)
# Data Fetched for Blue Jasmine
# Data Fetched for Blue Jasmine
# Data Fetched for Blue Jasmine
# Data Fetched for Blue Jasmine
# Data Fetched for Mr Hublot
# Data Fetched for Mr Hublot
# Data Fetched for Mr Hublot
# Data Fetched for Mr Hublot
# Data Fetched for The Lady in Number 6
# Data Fetched for The Lady in Number 6
# Data Fetched for The Lady in Number 6
# Data Fetched for The Lady in Number 6
# Data Fetched for Helium (film)
# Data Fetched for Helium (film)
# Data Fetched for Helium (film)
# Data Fetched for Helium (film)
# Data Fetched for The Great Beauty
# Data Fetched for The Great Beauty
# Data Fetched for The Great Beauty
# Data Fetched for The Great Beauty
# Data Fetched for 20 Feet from Stardom
# Data Fetched for 20 Feet from Stardom
# Data Fetched for 20 Feet from Stardom
# Data Fetched for 20 Feet from Stardom
# Data Fetched for Argo (2012 film)
# Data Fetched for Argo (2012 film)
# Data Fetched for Argo (2012 film)
# Data Fetched for Argo (2012 film)
# Data Fetched for Life of Pi (film)
# Data Fetched for Life of Pi (film)
# Data Fetched for Life of Pi (film)
# Data Fetched for Life of Pi (film)
# Data Fetched for Les Misérables (2012 film)
# Data Fetched for Les Misérables (2012 film)
# Data Fetched for Les Misérables (2012 film)
# Data Fetched for Les Misérables (2012 film)
# Data Fetched for Lincoln (film)
# Data Fetched for Lincoln (film)
# Data Fetched for Lincoln (film)
# Data Fetched for Lincoln (film)
# Data Fetched for Django Unchained
# Data Fetched for Django Unchained
# Data Fetched for Django Unchained
# Data Fetched for Django Unchained
# Data Fetched for Skyfall
# Data Fetched for Skyfall
# Data Fetched for Skyfall
# Data Fetched for Skyfall
# Data Fetched for Silver Linings Playbook
# Data Fetched for Silver Linings Playbook
# Data Fetched for Silver Linings Playbook
# Data Fetched for Silver Linings Playbook
# Data Fetched for Zero Dark Thirty
# Data Fetched for Zero Dark Thirty
# Data Fetched for Zero Dark Thirty
# Data Fetched for Zero Dark Thirty
# Data Fetched for Amour (2012 film)
# Data Fetched for Amour (2012 film)
# Data Fetched for Amour (2012 film)
# Data Fetched for Amour (2012 film)
# Data Fetched for Anna Karenina (2012 film)
# Data Fetched for Anna Karenina (2012 film)
# Data Fetched for Anna Karenina (2012 film)
# Data Fetched for Anna Karenina (2012 film)
# Data Fetched for Paperman
# Data Fetched for Paperman
# Data Fetched for Paperman
# Data Fetched for Paperman
# Data Fetched for Brave (2012 film)
# Data Fetched for Brave (2012 film)
# Data Fetched for Brave (2012 film)
# Data Fetched for Brave (2012 film)
# Data Fetched for Searching for Sugar Man
# Data Fetched for Searching for Sugar Man
# Data Fetched for Searching for Sugar Man
# Data Fetched for Searching for Sugar Man
# Data Fetched for Inocente
# Data Fetched for Inocente
# Data Fetched for Inocente
# Data Fetched for Inocente
# Data Fetched for Curfew (2012 film)
# Data Fetched for Curfew (2012 film)
# Data Fetched for Curfew (2012 film)
# Data Fetched for Curfew (2012 film)
# Data Fetched for The Artist (film)
# Data Fetched for The Artist (film)
# Data Fetched for The Artist (film)
# Data Fetched for The Artist (film)
# Data Fetched for Hugo (film)
# Data Fetched for Hugo (film)
# Data Fetched for Hugo (film)
# Data Fetched for Hugo (film)
# Data Fetched for The Iron Lady (film)
# Data Fetched for The Iron Lady (film)
# Data Fetched for The Iron Lady (film)
# Data Fetched for The Iron Lady (film)
# Data Fetched for The Descendants
# Data Fetched for The Descendants
# Data Fetched for The Descendants
# Data Fetched for The Descendants
# Data Fetched for The Girl with the Dragon Tattoo (2011 film)
# Data Fetched for The Girl with the Dragon Tattoo (2011 film)
# Data Fetched for The Girl with the Dragon Tattoo (2011 film)
# Data Fetched for The Girl with the Dragon Tattoo (2011 film)
# Data Fetched for Midnight in Paris
# Data Fetched for Midnight in Paris
# Data Fetched for Midnight in Paris
# Data Fetched for Midnight in Paris
# Data Fetched for The Help (film)
# Data Fetched for The Help (film)
# Data Fetched for The Help (film)
# Data Fetched for The Help (film)
# Data Fetched for A Separation
# Data Fetched for A Separation
# Data Fetched for A Separation
# Data Fetched for A Separation
# Data Fetched for The Fantastic Flying Books of Mr. Morris Lessmore
# Data Fetched for The Fantastic Flying Books of Mr. Morris Lessmore
# Data Fetched for The Fantastic Flying Books of Mr. Morris Lessmore
# Data Fetched for The Fantastic Flying Books of Mr. Morris Lessmore
# Data Fetched for The Shore (2011 film)
# Data Fetched for The Shore (2011 film)
# Data Fetched for The Shore (2011 film)
# Data Fetched for The Shore (2011 film)
# Data Fetched for Undefeated (2011 film)
# Data Fetched for Undefeated (2011 film)
# Data Fetched for Undefeated (2011 film)
# Data Fetched for Undefeated (2011 film)
# Data Fetched for The Muppets (film)
# Data Fetched for The Muppets (film)
# Data Fetched for The Muppets (film)
# Data Fetched for The Muppets (film)
# Data Fetched for Saving Face (2012 film)
# Data Fetched for Saving Face (2012 film)
# Data Fetched for Saving Face (2012 film)
# Data Fetched for Saving Face (2012 film)
# Data Fetched for Beginners
# Data Fetched for Beginners
# Data Fetched for Beginners
# Data Fetched for Beginners
# Data Fetched for Rango (2011 film)
# Data Fetched for Rango (2011 film)
# Data Fetched for Rango (2011 film)
# Data Fetched for Rango (2011 film)
# Data Fetched for The King's Speech
# Data Fetched for The King's Speech
# Data Fetched for The King's Speech
# Data Fetched for The King's Speech
# Data Fetched for Inception
# Data Fetched for Inception
# Data Fetched for Inception
# Data Fetched for Inception
# Data Fetched for The Social Network
# Data Fetched for The Social Network
# Data Fetched for The Social Network
# Data Fetched for The Social Network
# Data Fetched for The Fighter
# Data Fetched for The Fighter
# Data Fetched for The Fighter
# Data Fetched for The Fighter
# Data Fetched for Toy Story 3
# Data Fetched for Toy Story 3
# Data Fetched for Toy Story 3
# Data Fetched for Toy Story 3
# Data Fetched for Alice in Wonderland (2010 film)
# Data Fetched for Alice in Wonderland (2010 film)
# Data Fetched for Alice in Wonderland (2010 film)
# Data Fetched for Alice in Wonderland (2010 film)
# Data Fetched for Black Swan (film)
# Data Fetched for Black Swan (film)
# Data Fetched for Black Swan (film)
# Data Fetched for Black Swan (film)
# Data Fetched for In a Better World
# Data Fetched for In a Better World
# Data Fetched for In a Better World
# Data Fetched for In a Better World
# Data Fetched for The Lost Thing
# Data Fetched for The Lost Thing
# Data Fetched for The Lost Thing
# Data Fetched for The Lost Thing
# Data Fetched for God of Love (film)
# Data Fetched for God of Love (film)
# Data Fetched for God of Love (film)
# Data Fetched for God of Love (film)
# Data Fetched for The Wolfman (2010 film)
# Data Fetched for The Wolfman (2010 film)
# Data Fetched for The Wolfman (2010 film)
# Data Fetched for The Wolfman (2010 film)
# Data Fetched for Strangers No More
# Data Fetched for Strangers No More
# Data Fetched for Strangers No More
# Data Fetched for Strangers No More
# Data Fetched for Inside Job (2010 film)
# Data Fetched for Inside Job (2010 film)
# Data Fetched for Inside Job (2010 film)
# Data Fetched for Inside Job (2010 film)
# Data Fetched for The Hurt Locker
# Data Fetched for The Hurt Locker
# Data Fetched for The Hurt Locker
# Data Fetched for The Hurt Locker
# Data Fetched for Avatar (2009 film)
# Data Fetched for Avatar (2009 film)
# Data Fetched for Avatar (2009 film)
# Data Fetched for Avatar (2009 film)
# Data Fetched for Precious (film)
# Data Fetched for Precious (film)
# Data Fetched for Precious (film)
# Data Fetched for Precious (film)
# Data Fetched for Up (2009 film)
# Data Fetched for Up (2009 film)
# Data Fetched for Up (2009 film)
# Data Fetched for Up (2009 film)
# Data Fetched for Crazy Heart
# Data Fetched for Crazy Heart
# Data Fetched for Crazy Heart
# Data Fetched for Crazy Heart
# Data Fetched for Inglourious Basterds
# Data Fetched for Inglourious Basterds
# Data Fetched for Inglourious Basterds
# Data Fetched for Inglourious Basterds
# Data Fetched for Star Trek (film)
# Data Fetched for Star Trek (film)
# Data Fetched for Star Trek (film)
# Data Fetched for Star Trek (film)
# Data Fetched for The Young Victoria
# Data Fetched for The Young Victoria
# Data Fetched for The Young Victoria
# Data Fetched for The Young Victoria
# Data Fetched for The Blind Side (film)
# Data Fetched for The Blind Side (film)
# Data Fetched for The Blind Side (film)
# Data Fetched for The Blind Side (film)
# Data Fetched for Music by Prudence
# Data Fetched for Music by Prudence
# Data Fetched for Music by Prudence
# Data Fetched for Music by Prudence
# Data Fetched for The Secret in Their Eyes
# Data Fetched for The Secret in Their Eyes
# Data Fetched for The Secret in Their Eyes
# Data Fetched for The Secret in Their Eyes
# Data Fetched for The Cove (film)
# Data Fetched for The Cove (film)
# Data Fetched for The Cove (film)
# Data Fetched for The Cove (film)
# Data Fetched for The New Tenants
# Data Fetched for The New Tenants
# Data Fetched for The New Tenants
# Data Fetched for The New Tenants
# Data Fetched for Logorama
# Data Fetched for Logorama
# Data Fetched for Logorama
# Data Fetched for Logorama
# Data Fetched for Slumdog Millionaire
# Data Fetched for Slumdog Millionaire
# Data Fetched for Slumdog Millionaire
# Data Fetched for Slumdog Millionaire
# Data Fetched for The Curious Case of Benjamin Button (film)
# Data Fetched for The Curious Case of Benjamin Button (film)
# Data Fetched for The Curious Case of Benjamin Button (film)
# Data Fetched for The Curious Case of Benjamin Button (film)
# Data Fetched for Milk (2008 American film)
# Data Fetched for Milk (2008 American film)
# Data Fetched for Milk (2008 American film)
# Data Fetched for Milk (2008 American film)
# Data Fetched for The Dark Knight (film)
# Data Fetched for The Dark Knight (film)
# Data Fetched for The Dark Knight (film)
# Data Fetched for The Dark Knight (film)
# Data Fetched for WALL-E
# Data Fetched for WALL-E
# Data Fetched for WALL-E
# Data Fetched for WALL-E
# Data Fetched for The Reader (2008 film)
# Data Fetched for The Reader (2008 film)
# Data Fetched for The Reader (2008 film)
# Data Fetched for The Reader (2008 film)
# Data Fetched for The Duchess (film)
# Data Fetched for The Duchess (film)
# Data Fetched for The Duchess (film)
# Data Fetched for The Duchess (film)
# Data Fetched for Departures (2008 film)
# Data Fetched for Departures (2008 film)
# Data Fetched for Departures (2008 film)
# Data Fetched for Departures (2008 film)
# Data Fetched for Vicky Cristina Barcelona
# Data Fetched for Vicky Cristina Barcelona
# Data Fetched for Vicky Cristina Barcelona
# Data Fetched for Vicky Cristina Barcelona
# Data Fetched for Smile Pinki
# Data Fetched for Smile Pinki
# Data Fetched for Smile Pinki
# Data Fetched for Smile Pinki
# Data Fetched for Man on Wire
# Data Fetched for Man on Wire
# Data Fetched for Man on Wire
# Data Fetched for Man on Wire
# Data Fetched for Toyland (film)
# Data Fetched for Toyland (film)
# Data Fetched for Toyland (film)
# Data Fetched for Toyland (film)
# Data Fetched for La Maison en Petits Cubes
# Data Fetched for La Maison en Petits Cubes
# Data Fetched for La Maison en Petits Cubes
# Data Fetched for La Maison en Petits Cubes
# Data Fetched for No Country for Old Men (film)
# Data Fetched for No Country for Old Men (film)
# Data Fetched for No Country for Old Men (film)
# Data Fetched for No Country for Old Men (film)
# Data Fetched for The Bourne Ultimatum (film)
# Data Fetched for The Bourne Ultimatum (film)
# Data Fetched for The Bourne Ultimatum (film)
# Data Fetched for The Bourne Ultimatum (film)
# Data Fetched for There Will Be Blood
# Data Fetched for There Will Be Blood
# Data Fetched for There Will Be Blood
# Data Fetched for There Will Be Blood
# Data Fetched for La Vie en rose (film)
# Data Fetched for La Vie en rose (film)
# Data Fetched for La Vie en rose (film)
# Data Fetched for La Vie en rose (film)
# Data Fetched for Atonement (2007 film)
# Data Fetched for Atonement (2007 film)
# Data Fetched for Atonement (2007 film)
# Data Fetched for Atonement (2007 film)
# Data Fetched for Michael Clayton (film)
# Data Fetched for Michael Clayton (film)
# Data Fetched for Michael Clayton (film)
# Data Fetched for Michael Clayton (film)
# Data Fetched for Ratatouille (film)
# Data Fetched for Ratatouille (film)
# Data Fetched for Ratatouille (film)
# Data Fetched for Ratatouille (film)
# Data Fetched for Juno (film)
# Data Fetched for Juno (film)
# Data Fetched for Juno (film)
# Data Fetched for Juno (film)
# Data Fetched for Sweeney Todd: The Demon Barber of Fleet Street (2007 film)
# Data Fetched for Sweeney Todd: The Demon Barber of Fleet Street (2007 film)
# Data Fetched for Sweeney Todd: The Demon Barber of Fleet Street (2007 film)
# Data Fetched for Sweeney Todd: The Demon Barber of Fleet Street (2007 film)
# Data Fetched for The Golden Compass (film)
# Data Fetched for The Golden Compass (film)
# Data Fetched for The Golden Compass (film)
# Data Fetched for The Golden Compass (film)
# Data Fetched for Elizabeth: The Golden Age
# Data Fetched for Elizabeth: The Golden Age
# Data Fetched for Elizabeth: The Golden Age
# Data Fetched for Elizabeth: The Golden Age
# Data Fetched for Taxi to the Dark Side
# Data Fetched for Taxi to the Dark Side
# Data Fetched for Taxi to the Dark Side
# Data Fetched for Taxi to the Dark Side
# Data Fetched for Peter & the Wolf (2006 film)
# Data Fetched for Peter & the Wolf (2006 film)
# Data Fetched for Peter & the Wolf (2006 film)
# Data Fetched for Peter & the Wolf (2006 film)
# Data Fetched for Once (film)
# Data Fetched for Once (film)
# Data Fetched for Once (film)
# Data Fetched for Once (film)
# Data Fetched for Le Mozart des pickpockets
# Data Fetched for Le Mozart des pickpockets
# Data Fetched for Le Mozart des pickpockets
# Data Fetched for Le Mozart des pickpockets
# Data Fetched for The Counterfeiters (2007 film)
# Data Fetched for The Counterfeiters (2007 film)
# Data Fetched for The Counterfeiters (2007 film)
# Data Fetched for The Counterfeiters (2007 film)
# Data Fetched for Freeheld (2007 film)
# Data Fetched for Freeheld (2007 film)
# Data Fetched for Freeheld (2007 film)
# Data Fetched for Freeheld (2007 film)
# Data Fetched for The Departed
# Data Fetched for The Departed
# Data Fetched for The Departed
# Data Fetched for The Departed
# Data Fetched for Pan's Labyrinth
# Data Fetched for Pan's Labyrinth
# Data Fetched for Pan's Labyrinth
# Data Fetched for Pan's Labyrinth
# Data Fetched for Dreamgirls (film)
# Data Fetched for Dreamgirls (film)
# Data Fetched for Dreamgirls (film)
# Data Fetched for Dreamgirls (film)
# Data Fetched for Little Miss Sunshine
# Data Fetched for Little Miss Sunshine
# Data Fetched for Little Miss Sunshine
# Data Fetched for Little Miss Sunshine
# Data Fetched for An Inconvenient Truth
# Data Fetched for An Inconvenient Truth
# Data Fetched for An Inconvenient Truth
# Data Fetched for An Inconvenient Truth
# Data Fetched for Babel (film)
# Data Fetched for Babel (film)
# Data Fetched for Babel (film)
# Data Fetched for Babel (film)
# Data Fetched for The Queen (2006 film)
# Data Fetched for The Queen (2006 film)
# Data Fetched for The Queen (2006 film)
# Data Fetched for The Queen (2006 film)
# Data Fetched for Letters from Iwo Jima
# Data Fetched for Letters from Iwo Jima
# Data Fetched for Letters from Iwo Jima
# Data Fetched for Letters from Iwo Jima
# Data Fetched for Pirates of the Caribbean: Dead Man's Chest
# Data Fetched for Pirates of the Caribbean: Dead Man's Chest
# Data Fetched for Pirates of the Caribbean: Dead Man's Chest
# Data Fetched for Pirates of the Caribbean: Dead Man's Chest
# Data Fetched for The Danish Poet
# Data Fetched for The Danish Poet
# Data Fetched for The Danish Poet
# Data Fetched for The Danish Poet
# Data Fetched for Happy Feet
# Data Fetched for Happy Feet
# Data Fetched for Happy Feet
# Data Fetched for Happy Feet
# Data Fetched for The Last King of Scotland (film)
# Data Fetched for The Last King of Scotland (film)
# Data Fetched for The Last King of Scotland (film)
# Data Fetched for The Last King of Scotland (film)
# Data Fetched for The Lives of Others
# Data Fetched for The Lives of Others
# Data Fetched for The Lives of Others
# Data Fetched for The Lives of Others
# Data Fetched for Marie Antoinette (2006 film)
# Data Fetched for Marie Antoinette (2006 film)
# Data Fetched for Marie Antoinette (2006 film)
# Data Fetched for Marie Antoinette (2006 film)
# Data Fetched for West Bank Story
# Data Fetched for West Bank Story
# Data Fetched for West Bank Story
# Data Fetched for West Bank Story
# Data Fetched for The Blood of Yingzhou District
# Data Fetched for The Blood of Yingzhou District
# Data Fetched for The Blood of Yingzhou District
# Data Fetched for The Blood of Yingzhou District
# Data Fetched for Crash (2004 film)
# Data Fetched for Crash (2004 film)
# Data Fetched for Crash (2004 film)
# Data Fetched for Crash (2004 film)
# Data Fetched for Brokeback Mountain
# Data Fetched for Brokeback Mountain
# Data Fetched for Brokeback Mountain
# Data Fetched for Brokeback Mountain
# Data Fetched for Memoirs of a Geisha (film)
# Data Fetched for Memoirs of a Geisha (film)
# Data Fetched for Memoirs of a Geisha (film)
# Data Fetched for Memoirs of a Geisha (film)
# Data Fetched for King Kong (2005 film)
# Data Fetched for King Kong (2005 film)
# Data Fetched for King Kong (2005 film)
# Data Fetched for King Kong (2005 film)
# Data Fetched for Capote (film)
# Data Fetched for Capote (film)
# Data Fetched for Capote (film)
# Data Fetched for Capote (film)
# Data Fetched for Walk the Line
# Data Fetched for Walk the Line
# Data Fetched for Walk the Line
# Data Fetched for Walk the Line
# Data Fetched for The Constant Gardener (film)
# Data Fetched for The Constant Gardener (film)
# Data Fetched for The Constant Gardener (film)
# Data Fetched for The Constant Gardener (film)
# Data Fetched for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Data Fetched for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Data Fetched for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Data Fetched for The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Data Fetched for Hustle & Flow
# Data Fetched for Hustle & Flow
# Data Fetched for Hustle & Flow
# Data Fetched for Hustle & Flow
# Data Fetched for Syriana
# Data Fetched for Syriana
# Data Fetched for Syriana
# Data Fetched for Syriana
# Data Fetched for March of the Penguins
# Data Fetched for March of the Penguins
# Data Fetched for March of the Penguins
# Data Fetched for March of the Penguins
# Data Fetched for Six Shooter (film)
# Data Fetched for Six Shooter (film)
# Data Fetched for Six Shooter (film)
# Data Fetched for Six Shooter (film)
# Data Fetched for The Moon and the Son: An Imagined Conversation
# Data Fetched for The Moon and the Son: An Imagined Conversation
# Data Fetched for The Moon and the Son: An Imagined Conversation
# Data Fetched for The Moon and the Son: An Imagined Conversation
# Data Fetched for A Note of Triumph: The Golden Age of Norman Corwin
# Data Fetched for A Note of Triumph: The Golden Age of Norman Corwin
# Data Fetched for A Note of Triumph: The Golden Age of Norman Corwin
# Data Fetched for A Note of Triumph: The Golden Age of Norman Corwin
# Data Fetched for Tsotsi
# Data Fetched for Tsotsi
# Data Fetched for Tsotsi
# Data Fetched for Tsotsi
# Data Fetched for Wallace & Gromit: The Curse of the Were-Rabbit
# Data Fetched for Wallace & Gromit: The Curse of the Were-Rabbit
# Data Fetched for Wallace & Gromit: The Curse of the Were-Rabbit
# Data Fetched for Wallace & Gromit: The Curse of the Were-Rabbit
# Data Fetched for Million Dollar Baby
# Data Fetched for Million Dollar Baby
# Data Fetched for Million Dollar Baby
# Data Fetched for Million Dollar Baby
# Data Fetched for The Aviator (2004 film)
# Data Fetched for The Aviator (2004 film)
# Data Fetched for The Aviator (2004 film)
# Data Fetched for The Aviator (2004 film)
# Data Fetched for Ray (film)
# Data Fetched for Ray (film)
# Data Fetched for Ray (film)
# Data Fetched for Ray (film)
# Data Fetched for The Incredibles
# Data Fetched for The Incredibles
# Data Fetched for The Incredibles
# Data Fetched for The Incredibles
# Data Fetched for Finding Neverland (film)
# Data Fetched for Finding Neverland (film)
# Data Fetched for Finding Neverland (film)
# Data Fetched for Finding Neverland (film)
# Data Fetched for Sideways
# Data Fetched for Sideways
# Data Fetched for Sideways
# Data Fetched for Sideways
# Data Fetched for Lemony Snicket's A Series of Unfortunate Events
# Data Fetched for Lemony Snicket's A Series of Unfortunate Events
# Data Fetched for Lemony Snicket's A Series of Unfortunate Events
# Data Fetched for Lemony Snicket's A Series of Unfortunate Events
# Data Fetched for Spider-Man 2
# Data Fetched for Spider-Man 2
# Data Fetched for Spider-Man 2
# Data Fetched for Spider-Man 2
# Data Fetched for Eternal Sunshine of the Spotless Mind
# Data Fetched for Eternal Sunshine of the Spotless Mind
# Data Fetched for Eternal Sunshine of the Spotless Mind
# Data Fetched for Eternal Sunshine of the Spotless Mind
# Data Fetched for The Motorcycle Diaries (film)
# Data Fetched for The Motorcycle Diaries (film)
# Data Fetched for The Motorcycle Diaries (film)
# Data Fetched for The Motorcycle Diaries (film)
# Data Fetched for The Sea Inside
# Data Fetched for The Sea Inside
# Data Fetched for The Sea Inside
# Data Fetched for The Sea Inside
# Data Fetched for Born into Brothels
# Data Fetched for Born into Brothels
# Data Fetched for Born into Brothels
# Data Fetched for Born into Brothels
# Data Fetched for Mighty Times: The Children's March
# Data Fetched for Mighty Times: The Children's March
# Data Fetched for Mighty Times: The Children's March
# Data Fetched for Mighty Times: The Children's March
# Data Fetched for Wasp (2003 film)
# Data Fetched for Wasp (2003 film)
# Data Fetched for Wasp (2003 film)
# Data Fetched for Wasp (2003 film)
# Data Fetched for Ryan (film)
# Data Fetched for Ryan (film)
# Data Fetched for Ryan (film)
# Data Fetched for Ryan (film)
# Data Fetched for The Lord of the Rings: The Return of the King
# Data Fetched for The Lord of the Rings: The Return of the King
# Data Fetched for The Lord of the Rings: The Return of the King
# Data Fetched for The Lord of the Rings: The Return of the King
# Data Fetched for Master and Commander: The Far Side of the World
# Data Fetched for Master and Commander: The Far Side of the World
# Data Fetched for Master and Commander: The Far Side of the World
# Data Fetched for Master and Commander: The Far Side of the World
# Data Fetched for Mystic River (film)
# Data Fetched for Mystic River (film)
# Data Fetched for Mystic River (film)
# Data Fetched for Mystic River (film)
# Data Fetched for Cold Mountain (film)
# Data Fetched for Cold Mountain (film)
# Data Fetched for Cold Mountain (film)
# Data Fetched for Cold Mountain (film)
# Data Fetched for Lost in Translation (film)
# Data Fetched for Lost in Translation (film)
# Data Fetched for Lost in Translation (film)
# Data Fetched for Lost in Translation (film)
# Data Fetched for Finding Nemo
# Data Fetched for Finding Nemo
# Data Fetched for Finding Nemo
# Data Fetched for Finding Nemo
# Data Fetched for The Barbarian Invasions
# Data Fetched for The Barbarian Invasions
# Data Fetched for The Barbarian Invasions
# Data Fetched for The Barbarian Invasions
# Data Fetched for Two Soldiers (2003 film)
# Data Fetched for Two Soldiers (2003 film)
# Data Fetched for Two Soldiers (2003 film)
# Data Fetched for Two Soldiers (2003 film)
# Data Fetched for Monster (2003 film)
# Data Fetched for Monster (2003 film)
# Data Fetched for Monster (2003 film)
# Data Fetched for Monster (2003 film)
# Data Fetched for Harvie Krumpet
# Data Fetched for Harvie Krumpet
# Data Fetched for Harvie Krumpet
# Data Fetched for Harvie Krumpet
# Data Fetched for Chernobyl Heart
# Data Fetched for Chernobyl Heart
# Data Fetched for Chernobyl Heart
# Data Fetched for Chernobyl Heart
# Data Fetched for The Fog of War
# Data Fetched for The Fog of War
# Data Fetched for The Fog of War
# Data Fetched for The Fog of War
# Data Fetched for Chicago (2002 film)
# Data Fetched for Chicago (2002 film)
# Data Fetched for Chicago (2002 film)
# Data Fetched for Chicago (2002 film)
# Data Fetched for The Pianist (2002 film)
# Data Fetched for The Pianist (2002 film)
# Data Fetched for The Pianist (2002 film)
# Data Fetched for The Pianist (2002 film)
# Data Fetched for The Lord of the Rings: The Two Towers
# Data Fetched for The Lord of the Rings: The Two Towers
# Data Fetched for The Lord of the Rings: The Two Towers
# Data Fetched for The Lord of the Rings: The Two Towers
# Data Fetched for Frida (film)
# Data Fetched for Frida (film)
# Data Fetched for Frida (film)
# Data Fetched for Frida (film)
# Data Fetched for The Hours (film)
# Data Fetched for The Hours (film)
# Data Fetched for The Hours (film)
# Data Fetched for The Hours (film)
# Data Fetched for Road to Perdition
# Data Fetched for Road to Perdition
# Data Fetched for Road to Perdition
# Data Fetched for Road to Perdition
# Data Fetched for Adaptation (film)
# Data Fetched for Adaptation (film)
# Data Fetched for Adaptation (film)
# Data Fetched for Adaptation (film)
# Data Fetched for Talk to Her
# Data Fetched for Talk to Her
# Data Fetched for Talk to Her
# Data Fetched for Talk to Her
# Data Fetched for This Charming Man (film)
# Data Fetched for This Charming Man (film)
# Data Fetched for This Charming Man (film)
# Data Fetched for This Charming Man (film)
# Data Fetched for Spirited Away
# Data Fetched for Spirited Away
# Data Fetched for Spirited Away
# Data Fetched for Spirited Away
# Data Fetched for Nowhere in Africa
# Data Fetched for Nowhere in Africa
# Data Fetched for Nowhere in Africa
# Data Fetched for Nowhere in Africa
# Data Fetched for The ChubbChubbs!
# Data Fetched for The ChubbChubbs!
# Data Fetched for The ChubbChubbs!
# Data Fetched for The ChubbChubbs!
# Data Fetched for Twin Towers (film)
# Data Fetched for Twin Towers (film)
# Data Fetched for Twin Towers (film)
# Data Fetched for Twin Towers (film)
# Data Fetched for Bowling for Columbine
# Data Fetched for Bowling for Columbine
# Data Fetched for Bowling for Columbine
# Data Fetched for Bowling for Columbine
# Data Fetched for 8 Mile (film)
# Data Fetched for 8 Mile (film)
# Data Fetched for 8 Mile (film)
# Data Fetched for 8 Mile (film)
# Data Fetched for A Beautiful Mind (film)
# Data Fetched for A Beautiful Mind (film)
# Data Fetched for A Beautiful Mind (film)
# Data Fetched for A Beautiful Mind (film)
# Data Fetched for The Lord of the Rings: The Fellowship of the Ring
# Data Fetched for The Lord of the Rings: The Fellowship of the Ring
# Data Fetched for The Lord of the Rings: The Fellowship of the Ring
# Data Fetched for The Lord of the Rings: The Fellowship of the Ring
# Data Fetched for Moulin Rouge!
# Data Fetched for Moulin Rouge!
# Data Fetched for Moulin Rouge!
# Data Fetched for Moulin Rouge!
# Data Fetched for Black Hawk Down (film)
# Data Fetched for Black Hawk Down (film)
# Data Fetched for Black Hawk Down (film)
# Data Fetched for Black Hawk Down (film)
# Data Fetched for Gosford Park
# ...
# Data Fetched for Survival City
# Data Fetched for Survival City
# Data Fetched for Survival City
# Data Fetched for Suspicion (1941 film)
# Data Fetched for Suspicion (1941 film)
# Data Fetched for Suspicion (1941 film)
# Data Fetched for Suspicion (1941 film)
# Data Fetched for Sweet Bird of Youth (1962 film)
# Data Fetched for Sweet Bird of Youth (1962 film)
# Data Fetched for Sweet Bird of Youth (1962 film)
# Data Fetched for Sweet Bird of Youth (1962 film)
# Data Fetched for Sweethearts (1938 film)
# Data Fetched for Sweethearts (1938 film)
# Data Fetched for Sweethearts (1938 film)
# Data Fetched for Sweethearts (1938 film)
# Data Fetched for Swing Time (film)
# Data Fetched for Swing Time (film)
# Data Fetched for Swing Time (film)
# Data Fetched for Swing Time (film)
# Data Fetched for Symphony of a City
# Data Fetched for Symphony of a City
# Data Fetched for Symphony of a City
# Data Fetched for Symphony of a City
# Data Fetched for Tabu: A Story of the South Seas
# Data Fetched for Tabu: A Story of the South Seas
# Data Fetched for Tabu: A Story of the South Seas
# Data Fetched for Tabu: A Story of the South Seas
# Data Fetched for Target for Tonight
# Data Fetched for Target for Tonight
# Data Fetched for Target for Tonight
# Data Fetched for Target for Tonight
# Data Fetched for Teddy, the Rough Rider
# Data Fetched for Teddy, the Rough Rider
# Data Fetched for Teddy, the Rough Rider
# Data Fetched for Teddy, the Rough Rider
# Data Fetched for Tempest (1928 film)
# Data Fetched for Tempest (1928 film)
# Data Fetched for Tempest (1928 film)
# Data Fetched for Tempest (1928 film)
# Data Fetched for The Ten Commandments (1956 film)
# Data Fetched for The Ten Commandments (1956 film)
# Data Fetched for The Ten Commandments (1956 film)
# Data Fetched for The Ten Commandments (1956 film)
# Data Fetched for That Hamilton Woman
# Data Fetched for That Hamilton Woman
# Data Fetched for That Hamilton Woman
# Data Fetched for That Hamilton Woman
# Data Fetched for That Mothers Might Live
# Data Fetched for That Mothers Might Live
# Data Fetched for That Mothers Might Live
# Data Fetched for That Mothers Might Live
# Data Fetched for The Thief of Bagdad (1940 film)
# Data Fetched for The Thief of Bagdad (1940 film)
# Data Fetched for The Thief of Bagdad (1940 film)
# Data Fetched for The Thief of Bagdad (1940 film)
# Data Fetched for The Third Man
# Data Fetched for The Third Man
# Data Fetched for The Third Man
# Data Fetched for The Third Man
# Data Fetched for Thirty Seconds Over Tokyo
# Data Fetched for Thirty Seconds Over Tokyo
# Data Fetched for Thirty Seconds Over Tokyo
# Data Fetched for Thirty Seconds Over Tokyo
# Data Fetched for This Above All (film)
# Data Fetched for This Above All (film)
# Data Fetched for This Above All (film)
# Data Fetched for This Above All (film)
# Data Fetched for This Is the Army
# Data Fetched for This Is the Army
# Data Fetched for This Is the Army
# Data Fetched for This Is the Army
# Data Fetched for This Land Is Mine (film)
# Data Fetched for This Land Is Mine (film)
# Data Fetched for This Land Is Mine (film)
# Data Fetched for This Land Is Mine (film)
# Data Fetched for This Mechanical Age
# Data Fetched for This Mechanical Age
# Data Fetched for This Mechanical Age
# Data Fetched for This Mechanical Age
# Data Fetched for Three Coins in the Fountain (film)
# Data Fetched for Three Coins in the Fountain (film)
# Data Fetched for Three Coins in the Fountain (film)
# Data Fetched for Three Coins in the Fountain (film)
# Data Fetched for The Three Faces of Eve
# Data Fetched for The Three Faces of Eve
# Data Fetched for The Three Faces of Eve
# Data Fetched for The Three Faces of Eve
# Data Fetched for Three Little Pigs (film)
# Data Fetched for Three Little Pigs (film)
# Data Fetched for Three Little Pigs (film)
# Data Fetched for Three Little Pigs (film)
# Data Fetched for Three Orphan Kittens
# Data Fetched for Three Orphan Kittens
# Data Fetched for Three Orphan Kittens
# Data Fetched for Three Orphan Kittens
# Data Fetched for Through a Glass Darkly (film)
# Data Fetched for Through a Glass Darkly (film)
# Data Fetched for Through a Glass Darkly (film)
# Data Fetched for Through a Glass Darkly (film)
# Data Fetched for Thunderball (film)
# Data Fetched for Thunderball (film)
# Data Fetched for Thunderball (film)
# Data Fetched for Thunderball (film)
# Data Fetched for Thursday's Children
# Data Fetched for Thursday's Children
# Data Fetched for Thursday's Children
# Data Fetched for Thursday's Children
# Data Fetched for The Time Machine (1960 film)
# Data Fetched for The Time Machine (1960 film)
# Data Fetched for The Time Machine (1960 film)
# Data Fetched for The Time Machine (1960 film)
# Data Fetched for A Time Out of War
# Data Fetched for A Time Out of War
# Data Fetched for A Time Out of War
# Data Fetched for A Time Out of War
# Data Fetched for Tin Pan Alley (film)
# Data Fetched for Tin Pan Alley (film)
# Data Fetched for Tin Pan Alley (film)
# Data Fetched for Tin Pan Alley (film)
# Data Fetched for The Titan: Story of Michelangelo
# Data Fetched for The Titan: Story of Michelangelo
# Data Fetched for The Titan: Story of Michelangelo
# Data Fetched for The Titan: Story of Michelangelo
# Data Fetched for Titanic (1953 film)
# Data Fetched for Titanic (1953 film)
# Data Fetched for Titanic (1953 film)
# Data Fetched for Titanic (1953 film)
# Data Fetched for To Catch a Thief
# Data Fetched for To Catch a Thief
# Data Fetched for To Catch a Thief
# Data Fetched for To Catch a Thief
# Data Fetched for To Each His Own (1946 film)
# Data Fetched for To Each His Own (1946 film)
# Data Fetched for To Each His Own (1946 film)
# Data Fetched for To Each His Own (1946 film)
# Data Fetched for To Kill a Mockingbird (film)
# Data Fetched for To Kill a Mockingbird (film)
# Data Fetched for To Kill a Mockingbird (film)
# Data Fetched for To Kill a Mockingbird (film)
# Data Fetched for Tom Jones (1963 film)
# Data Fetched for Tom Jones (1963 film)
# Data Fetched for Tom Jones (1963 film)
# Data Fetched for Tom Jones (1963 film)
# Data Fetched for Tom Thumb (film)
# Data Fetched for Tom Thumb (film)
# Data Fetched for Tom Thumb (film)
# Data Fetched for Tom Thumb (film)
# Data Fetched for Toot, Whistle, Plunk and Boom
# Data Fetched for Toot, Whistle, Plunk and Boom
# Data Fetched for Toot, Whistle, Plunk and Boom
# Data Fetched for Toot, Whistle, Plunk and Boom
# Data Fetched for Topkapi (film)
# Data Fetched for Topkapi (film)
# Data Fetched for Topkapi (film)
# Data Fetched for Topkapi (film)
# Data Fetched for The Tortoise and the Hare (film)
# Data Fetched for The Tortoise and the Hare (film)
# Data Fetched for The Tortoise and the Hare (film)
# Data Fetched for The Tortoise and the Hare (film)
# Data Fetched for Torture Money
# Data Fetched for Torture Money
# Data Fetched for Torture Money
# Data Fetched for Torture Money
# Data Fetched for Toward Independence
# Data Fetched for Toward Independence
# Data Fetched for Toward Independence
# Data Fetched for Toward Independence
# Data Fetched for Transatlantic (1931 film)
# Data Fetched for Transatlantic (1931 film)
# Data Fetched for Transatlantic (1931 film)
# Data Fetched for Transatlantic (1931 film)
# Data Fetched for The Treasure of the Sierra Madre (film)
# Data Fetched for The Treasure of the Sierra Madre (film)
# Data Fetched for The Treasure of the Sierra Madre (film)
# Data Fetched for The Treasure of the Sierra Madre (film)
# Data Fetched for A Tree Grows in Brooklyn (1945 film)
# Data Fetched for A Tree Grows in Brooklyn (1945 film)
# Data Fetched for A Tree Grows in Brooklyn (1945 film)
# Data Fetched for A Tree Grows in Brooklyn (1945 film)
# Data Fetched for The True Glory
# Data Fetched for The True Glory
# Data Fetched for The True Glory
# Data Fetched for The True Glory
# Data Fetched for The True Story of the Civil War
# Data Fetched for The True Story of the Civil War
# Data Fetched for The True Story of the Civil War
# Data Fetched for The True Story of the Civil War
# Data Fetched for Tweetie Pie
# Data Fetched for Tweetie Pie
# Data Fetched for Tweetie Pie
# Data Fetched for Tweetie Pie
# Data Fetched for Twelve O'Clock High
# Data Fetched for Twelve O'Clock High
# Data Fetched for Twelve O'Clock High
# Data Fetched for Twelve O'Clock High
# Data Fetched for Two Arabian Knights
# Data Fetched for Two Arabian Knights
# Data Fetched for Two Arabian Knights
# Data Fetched for Two Arabian Knights
# Data Fetched for The Two Mouseketeers
# Data Fetched for The Two Mouseketeers
# Data Fetched for The Two Mouseketeers
# Data Fetched for The Two Mouseketeers
# Data Fetched for Two Women
# Data Fetched for Two Women
# Data Fetched for Two Women
# Data Fetched for Two Women
# Data Fetched for The Ugly Duckling (1939 film)
# Data Fetched for The Ugly Duckling (1939 film)
# Data Fetched for The Ugly Duckling (1939 film)
# Data Fetched for The Ugly Duckling (1939 film)
# Data Fetched for Underworld (1927 film)
# Data Fetched for Underworld (1927 film)
# Data Fetched for Underworld (1927 film)
# Data Fetched for Underworld (1927 film)
# Data Fetched for The V.I.P.s (film)
# Data Fetched for The V.I.P.s (film)
# Data Fetched for The V.I.P.s (film)
# Data Fetched for The V.I.P.s (film)
# Data Fetched for Perfect Strangers (1945 film)
# Data Fetched for Perfect Strangers (1945 film)
# Data Fetched for Perfect Strangers (1945 film)
# Data Fetched for Perfect Strangers (1945 film)
# Data Fetched for Van Gogh (1948 film)
# Data Fetched for Van Gogh (1948 film)
# Data Fetched for Van Gogh (1948 film)
# Data Fetched for Van Gogh (1948 film)
# Data Fetched for The Vanishing Prairie
# Data Fetched for The Vanishing Prairie
# Data Fetched for The Vanishing Prairie
# Data Fetched for The Vanishing Prairie
# Data Fetched for The Virgin Spring
# Data Fetched for The Virgin Spring
# Data Fetched for The Virgin Spring
# Data Fetched for The Virgin Spring
# Data Fetched for Viva Villa!
# Data Fetched for Viva Villa!
# Data Fetched for Viva Villa!
# Data Fetched for Viva Villa!
# Data Fetched for Viva Zapata!
# Data Fetched for Viva Zapata!
# Data Fetched for Viva Zapata!
# Data Fetched for Viva Zapata!
# Data Fetched for Waikiki Wedding
# Data Fetched for Waikiki Wedding
# Data Fetched for Waikiki Wedding
# Data Fetched for Waikiki Wedding
# Data Fetched for The Walls of Malapaga
# Data Fetched for The Walls of Malapaga
# Data Fetched for The Walls of Malapaga
# Data Fetched for The Walls of Malapaga
# Data Fetched for The War of the Worlds (1953 film)
# Data Fetched for The War of the Worlds (1953 film)
# Data Fetched for The War of the Worlds (1953 film)
# Data Fetched for The War of the Worlds (1953 film)
# Data Fetched for Watch on the Rhine
# Data Fetched for Watch on the Rhine
# Data Fetched for Watch on the Rhine
# Data Fetched for Watch on the Rhine
# Data Fetched for Water Birds
# Data Fetched for Water Birds
# Data Fetched for Water Birds
# Data Fetched for Water Birds
# Data Fetched for The Way of All Flesh (1927 film)
# Data Fetched for The Way of All Flesh (1927 film)
# Data Fetched for The Way of All Flesh (1927 film)
# Data Fetched for The Way of All Flesh (1927 film)
# Data Fetched for West Side Story (1961 film)
# Data Fetched for West Side Story (1961 film)
# Data Fetched for West Side Story (1961 film)
# Data Fetched for West Side Story (1961 film)
# Data Fetched for The Westerner (1940 film)
# Data Fetched for The Westerner (1940 film)
# Data Fetched for The Westerner (1940 film)
# Data Fetched for The Westerner (1940 film)
# Data Fetched for The Wetback Hound
# Data Fetched for The Wetback Hound
# Data Fetched for The Wetback Hound
# Data Fetched for The Wetback Hound
# Data Fetched for What Ever Happened to Baby Jane? (1962 film)
# Data Fetched for What Ever Happened to Baby Jane? (1962 film)
# Data Fetched for What Ever Happened to Baby Jane? (1962 film)
# Data Fetched for What Ever Happened to Baby Jane? (1962 film)
# Data Fetched for When Tomorrow Comes (film)
# Data Fetched for When Tomorrow Comes (film)
# Data Fetched for When Tomorrow Comes (film)
# Data Fetched for When Tomorrow Comes (film)
# Data Fetched for When Magoo Flew
# Data Fetched for When Magoo Flew
# Data Fetched for When Magoo Flew
# Data Fetched for When Magoo Flew
# Data Fetched for When Worlds Collide (1951 film)
# Data Fetched for When Worlds Collide (1951 film)
# Data Fetched for When Worlds Collide (1951 film)
# Data Fetched for When Worlds Collide (1951 film)
# Data Fetched for White Shadows in the South Seas
# Data Fetched for White Shadows in the South Seas
# Data Fetched for White Shadows in the South Seas
# Data Fetched for White Shadows in the South Seas
# Data Fetched for White Wilderness (film)
# Data Fetched for White Wilderness (film)
# Data Fetched for White Wilderness (film)
# Data Fetched for White Wilderness (film)
# Data Fetched for Who's Who in Animal Land
# Data Fetched for Who's Who in Animal Land
# Data Fetched for Who's Who in Animal Land
# Data Fetched for Who's Who in Animal Land
# Data Fetched for Why Korea?
# Data Fetched for Why Korea?
# Data Fetched for Why Korea?
# Data Fetched for Why Korea?
# Data Fetched for Wilson (1944 film)
# Data Fetched for Wilson (1944 film)
# Data Fetched for Wilson (1944 film)
# Data Fetched for Wilson (1944 film)
# Data Fetched for Wings (1927 film)
# Data Fetched for Wings (1927 film)
# Data Fetched for Wings (1927 film)
# Data Fetched for Wings (1927 film)
# Data Fetched for Wings Over Everest
# Data Fetched for Wings Over Everest
# Data Fetched for Wings Over Everest
# Data Fetched for Wings Over Everest
# Data Fetched for With a Song in My Heart (film)
# Data Fetched for With a Song in My Heart (film)
# Data Fetched for With a Song in My Heart (film)
# Data Fetched for With a Song in My Heart (film)
# Data Fetched for With Byrd at the South Pole
# Data Fetched for With Byrd at the South Pole
# Data Fetched for With Byrd at the South Pole
# Data Fetched for With Byrd at the South Pole
# Data Fetched for With the Marines at Tarawa
# Data Fetched for With the Marines at Tarawa
# Data Fetched for With the Marines at Tarawa
# Data Fetched for With the Marines at Tarawa
# Data Fetched for The Wizard of Oz (1939 film)
# Data Fetched for The Wizard of Oz (1939 film)
# Data Fetched for The Wizard of Oz (1939 film)
# Data Fetched for The Wizard of Oz (1939 film)
# Data Fetched for Woman of the Year
# Data Fetched for Woman of the Year
# Data Fetched for Woman of the Year
# Data Fetched for Woman of the Year
# Data Fetched for Wonder Man (film)
# Data Fetched for Wonder Man (film)
# Data Fetched for Wonder Man (film)
# Data Fetched for Wonder Man (film)
# Data Fetched for The Wonderful World of the Brothers Grimm
# Data Fetched for The Wonderful World of the Brothers Grimm
# Data Fetched for The Wonderful World of the Brothers Grimm
# Data Fetched for The Wonderful World of the Brothers Grimm
# Data Fetched for World of Kids
# Data Fetched for World of Kids
# Data Fetched for World of Kids
# Data Fetched for World of Kids
# Data Fetched for World Without Sun
# Data Fetched for World Without Sun
# Data Fetched for World Without Sun
# Data Fetched for World Without Sun
# Data Fetched for Wrestling Swordfish
# Data Fetched for Wrestling Swordfish
# Data Fetched for Wrestling Swordfish
# Data Fetched for Wrestling Swordfish
# Data Fetched for Written on the Wind
# Data Fetched for Written on the Wind
# Data Fetched for Written on the Wind
# Data Fetched for Written on the Wind
# Data Fetched for Wuthering Heights (1939 film)
# Data Fetched for Wuthering Heights (1939 film)
# Data Fetched for Wuthering Heights (1939 film)
# Data Fetched for Wuthering Heights (1939 film)
# Data Fetched for Yankee Doodle Dandy
# Data Fetched for Yankee Doodle Dandy
# Data Fetched for Yankee Doodle Dandy
# Data Fetched for Yankee Doodle Dandy
# Data Fetched for The Yankee Doodle Mouse
# Data Fetched for The Yankee Doodle Mouse
# Data Fetched for The Yankee Doodle Mouse
# Data Fetched for The Yankee Doodle Mouse
# Data Fetched for The Yearling (1946 film)
# Data Fetched for The Yearling (1946 film)
# Data Fetched for The Yearling (1946 film)
# Data Fetched for The Yearling (1946 film)
# Data Fetched for Yesterday, Today and Tomorrow
# Data Fetched for Yesterday, Today and Tomorrow
# Data Fetched for Yesterday, Today and Tomorrow
# Data Fetched for Yesterday, Today and Tomorrow
# Data Fetched for You Can't Take It with You (film)
# Data Fetched for You Can't Take It with You (film)
# Data Fetched for You Can't Take It with You (film)
# Data Fetched for You Can't Take It with You (film)
# Data Fetched for Zorba the Greek (film)
# Data Fetched for Zorba the Greek (film)
# Data Fetched for Zorba the Greek (film)
# Data Fetched for Zorba the Greek (film)

# %% [markdown]
# ### The API Call failed for Victor/Victoria

# %%
final_data = pd.concat(filtered_data)
final_data.shape
# Out:
# (515440, 7)

# %%
final_data.loc[(final_data['article'] == 'Everything_Everywhere_All_at_Once') & (final_data ['timestamp'] == '2020010100')]
# Out:
#         project                            article granularity   timestamp  \
# 0  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020010100
# 0  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020010100
# 0  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020010100
# 0  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020010100
#
#        access agent  views
# 0  all-access  user   3515
# 0     desktop  user   1209
# 0  mobile-web  user   2241
# 0  mobile-app  user     65

# %%
final_data.to_csv('../Data/Processed_Data.csv')
final_data.shape
# Out:
# (515440, 7)

# %% [markdown]
# ## Creating Json Files

# %%
final_data.access.value_counts()
df = final_data.copy(deep=True)

# %%
df.loc[df['access'] =='all-access', 'access'] = 'cumulative'
df.loc[df['access'] =='desktop', 'access'] = 'desktop'
df.loc[((df['access'] == 'mobile-app') | (df['access'] == 'mobile-web')), 'access'] = 'mobile'
df.head()
# Out:
#         project                            article granularity   timestamp  \
# 0  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020010100
# 1  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020020100
# 2  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020030100
# 3  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020040100
# 4  en.wikipedia  Everything_Everywhere_All_at_Once     monthly  2020050100
#
#        access agent  views
# 0  cumulative  user   3515
# 1  cumulative  user   8051
# 2  cumulative  user   7159
# 3  cumulative  user  14354
# 4  cumulative  user  12061

# %%
final_df = df.groupby(['project','article','granularity','timestamp','access','agent'])['views'].sum()

# %%
final_df = pd.DataFrame(final_df).reset_index()

# %%
final_df.sort_values(by = ['article','timestamp'], ascending =True)
final_df.shape
# Out:
# (386580, 7)

# %%
final_df
# Out:
#              project                  article granularity   timestamp  \
# 0       en.wikipedia  12_Years_a_Slave_(film)     monthly  2015070100
# 1       en.wikipedia  12_Years_a_Slave_(film)     monthly  2015070100
# 2       en.wikipedia  12_Years_a_Slave_(film)     monthly  2015070100
# 3       en.wikipedia  12_Years_a_Slave_(film)     monthly  2015080100
# 4       en.wikipedia  12_Years_a_Slave_(film)     monthly  2015080100
# ...              ...                      ...         ...         ...
# 386575  en.wikipedia   Zorba_the_Greek_(film)     monthly  2023080100
# 386576  en.wikipedia   Zorba_the_Greek_(film)     monthly  2023080100
# 386577  en.wikipedia   Zorba_the_Greek_(film)     monthly  2023090100
# 386578  en.wikipedia   Zorba_the_Greek_(film)     monthly  2023090100
# 386579  en.wikipedia   Zorba_the_Greek_(film)     monthly  2023090100
#
#             access agent   views
# 0       cumulative  user  138151
# 1          desktop  user   62693
# 2           mobile  user   75458
# 3       cumulative  user  122993
# 4          desktop  user   58902
# ...            ...   ...     ...
# 386575     desktop  user    5789
# 386576      mobile  user   13733
# 386577  cumulative  user   18216
# 386578     desktop  user    5113
# 386579      mobile  user   13103
#
# [386580 rows x 7 columns]

# %%
mobile_json = final_df.loc[final_df['access'] == 'mobile']
mobile_json.drop(['access'], axis= 1, inplace =True)
mobile_json = mobile_json.to_dict(orient='records')

desktop_json = final_df.loc[final_df['access'] == 'desktop']
desktop_json.drop(['access'], axis= 1, inplace =True)
desktop_json = desktop_json.to_dict(orient='records')

cumulative_json = final_df.loc[final_df['access'] == 'cumulative']
cumulative_json.drop(['access'], axis= 1, inplace =True)
cumulative_json = cumulative_json.to_dict(orient='records')
# Out:
# C:\Users\PRERIT\AppData\Local\Temp\ipykernel_26540\4204148835.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobile_json.drop(['access'], axis= 1, inplace =True)
# C:\Users\PRERIT\AppData\Local\Temp\ipykernel_26540\4204148835.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desktop_json.drop(['access'], axis= 1, inplace =True)
# C:\Users\PRERIT\AppData\Local\Temp\ipykernel_26540\4204148835.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cumulative_json.drop(['access'], axis= 1, inplace =True)

# %%
import json
with open(f"../Output and Results/academy_monthly_mobile_{201507}-{202309}.json", "w") as file:
    json.dump(mobile_json, file)
with open("../Output and Results/academy_monthly_desktop_201507-202309.json", "w") as file:
    json.dump(desktop_json, file)
with open("../Output and Results/academy_monthly_cumulative_201507-202309.json", "w") as file:
    json.dump(cumulative_json, file)

# %% [markdown]
# # First Analysis

# %%
desktop_json = json.load(open('../Output and Results/academy_monthly_desktop_201507-202309.json'))
mobile_json = json.load(open('../Output and Results/academy_monthly_mobile_201507-202309.json'))
desktop = pd.json_normalize(desktop_json)
mobile = pd.json_normalize(mobile_json)

# %%
def max_min_function(df, access):
    df['timestamp'] = df['timestamp'].astype('str')
    df['timestamp'] = pd.to_datetime(df['timestamp'], format = '%Y%m%d%H')
    g_data = df.groupby('article').mean('views')
    article_max = g_data.loc[g_data['views'].idxmax()].name
    article_min = g_data.loc[g_data['views'].idxmin()].name
    data_max = df[df['article'] == article_max][['timestamp', 'article', 'views']]
    data_min = df[df['article'] == article_min][['timestamp', 'article', 'views']]
    data_max['min_max'] = 'max_' + access
    data_max['label'] = data_max['min_max'] + '_' + data_max['article'] 
    data_min['min_max'] = 'min_' + access
    data_min['label'] = data_min['min_max'] + '_' + data_min['article']
    result_df = pd.concat([data_max, data_min])
    return result_df

# %%
desktop_main = max_min_function(desktop, access='desktop')
mobile_main = max_min_function(mobile, access='mobile')
df_main = pd.concat([desktop_main, mobile_main])
df_main = df_main.set_index('timestamp')

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
max_desktop_df = df_main[df_main['min_max']=='max_desktop']
max_desktop_df['views'].plot(label = max_desktop_df['label'].value_counts().index[0])
min_desktop_df = df_main[df_main['min_max']=='min_desktop']
min_desktop_df['views'].plot(label = min_desktop_df['label'].value_counts().index[0])
max_mobile_df = df_main[df_main['min_max']=='max_mobile']
max_mobile_df['views'].plot(label = max_mobile_df['label'].value_counts().index[0])
min_mobile_df = df_main[df_main['min_max']=='min_mobile']
min_mobile_df['views'].plot(label = min_mobile_df['label'].value_counts().index[0])
plt.title('Maximum and Minimum Average')
plt.xlabel('Timestamp')
plt.ylabel('Views')
fig.legend(loc="upper right", bbox_to_anchor=(0.15, 0.9))
plt.show()
plt.savefig('../Output and Results/Max_Min_plot.png')
plt.close()

# %% [markdown]
# # Second Analysis

# %%
def top_10_views_function(df, access):
    grouped = df.groupby('article').max('views').reset_index()
    grouped = grouped.sort_values(by='views', ascending=False)
    top10 = grouped.head(10)
    top10 = top10[['article']].reset_index(drop=True)
    top10['rank'] = pd.Series(np.arange(1,11))
    df['access'] = access
    df = df[['timestamp', 'article', 'access', 'views']]
    df = df.merge(only_top10, on='article', how='inner', suffixes=('_left', '_right'))
    df['label'] = 'top_' + df['rank'].astype('str') + access + '_' + df['article']
    return df
top_desktop = top_10_views_function(desktop, 'desktop')
top_mobile = top_10_views_function(mobile, 'mobile')
df_final = pd.concat([top_desktop, top_mobile])
df_final = df_final.set_index('timestamp')

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
for i in range(1,11):
    df = df_final[df_final['rank'] == i]
    df[df['access'] == 'desktop']['views'].plot(label=df['label'].value_counts().index[0])
    df[df['access'] == 'mobile']['views'].plot(label=df['label'].value_counts().index[1])
plt.title('Top 10 Peak Views')
plt.xlabel('Timestamp')
plt.ylabel('Views')
fig.legend(loc="upper right", bbox_to_anchor=(0.15, 0.9))
plt.show()
plt.savefig('../Output and Results/Top10_plot.png')
plt.close()

# %% [markdown]
# # Third Analysis

# %%
def fewest_months_function(df, access):
    few_df = df.groupby("article").count().reset_index()
    few_df = few_df[['article', 'views']]
    few_df = few_df.sort_values(by='views', ascending=True)
    top_10 = few_df.head(10)
    top_10 = top_10[['article']].reset_index()
    top_10 = top_10.drop('index', axis = 1)
    top_10['rank'] = pd.Series(np.arange(1,11))
    df['access'] = access
    df = df[['timestamp', 'article', 'access', 'views']]
    df = df.merge(top_10, on='article', how='inner', suffixes=('_left', '_right'))
    df['label'] = 'fewest_' + df['rank'].astype('str') + access + '_' + df['article']
    return df
top_desktop = fewest_months_function(desktop, 'desktop')
top_mobile = fewest_months_function(mobile, 'mobile')
df_final = pd.concat([top_desktop, top_mobile])
df_final = df_final.set_index('timestamp')

# %% [markdown]
# ### Visualization

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
for i in range(1,11):
    df = df_final[df_final['rank'] == i]
    df[df['access'] == 'desktop']['views'].plot(label=df['label'].value_counts().index[0])
    df[df['access'] == 'mobile']['views'].plot(label=df['label'].value_counts().index[1])
plt.title('Fewest Months')
plt.xlabel('Timestamp')
plt.ylabel('Views')
fig.legend(loc="upper right", bbox_to_anchor=(0.15, 0.9))
plt.show()
plt.savefig('../Output and Results/Fewest10_plot.png')
plt.close()
